# %% [markdown]
# <a href="https://colab.research.google.com/github/mmilannaik/BigOCheatSheet/blob/master/Big_Mart_ABB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import KFold, GroupKFold, cross_val_score
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, FunctionTransformer
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_squared_error, make_scorer
from sklearn.linear_model import LinearRegression, RidgeCV
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder

import warnings
warnings.filterwarnings("ignore")

# %%
train = pd.read_csv('/content/train.csv')
test = pd.read_csv('/content/test.csv')

# %% [markdown]
# # EDA

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %% [markdown]
# ## Data Wrangling

# %%
train['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
test['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'reg', 'Regular', 'LF', 'low fat'], dtype=object)

# %%
train['Item_Visibility'].unique()
# Out:
# array([0.0160473 , 0.01927822, 0.01676007, ..., 0.03518627, 0.14522065,
#        0.04487828])

# %%
len(train['Item_Identifier'].unique())
# Out:
# 1559

# %%
train[train['Item_Weight'].isna()].sample(4)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7425           FDB26          NaN          Regular         0.031116
# 2687           NCL53          NaN          Low Fat         0.000000
# 7747           FDE56          NaN          Regular         0.158425
# 6398           NCW18          NaN          Low Fat         0.059038
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7425                 Canned   55.2640            OUT027
# 2687     Health and Hygiene  175.4028            OUT027
# 7747  Fruits and Vegetables   62.4194            OUT027
# 6398              Household  237.7248            OUT027
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 7425                       1985      Medium               Tier 3
# 2687                       1985      Medium               Tier 3
# 7747                       1985      Medium               Tier 3
# 6398                       1985      Medium               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 7425  Supermarket Type3          1544.6560
# 2687  Supermarket Type3          6729.9064
# 7747  Supermarket Type3          2291.0178
# 6398  Supermarket Type3          2607.2728

# %%
train[train['Item_Visibility'].isna()]
# Out:
# Empty DataFrame
# Columns: [Item_Identifier, Item_Weight, Item_Fat_Content, Item_Visibility, Item_Type, Item_MRP, Outlet_Identifier, Outlet_Establishment_Year, Outlet_Size, Outlet_Location_Type, Outlet_Type, Item_Outlet_Sales]
# Index: []

# %%
train['Outlet_Size'].unique()
# Out:
# array(['Medium', nan, 'High', 'Small'], dtype=object)

# %%
train['Outlet_Type'].unique()
# Out:
# array(['Supermarket Type1', 'Supermarket Type2', 'Grocery Store',
#        'Supermarket Type3'], dtype=object)

# %%
train.groupby('Outlet_Type')['Outlet_Size'].agg(lambda x:x.mode())
# Out:
# Outlet_Type
# Grocery Store         Small
# Supermarket Type1     Small
# Supermarket Type2    Medium
# Supermarket Type3    Medium
# Name: Outlet_Size, dtype: object

# %%
train['Outlet_Size'].value_counts().idxmax()
# Out:
# 'Medium'

# %%
test.groupby('Outlet_Type')['Outlet_Size'].agg(lambda x:x.mode())
# Out:
# Outlet_Type
# Grocery Store         Small
# Supermarket Type1     Small
# Supermarket Type2    Medium
# Supermarket Type3    Medium
# Name: Outlet_Size, dtype: object

# %%
train['Outlet_Establishment_Year'].unique()
# Out:
# array([1999, 2009, 1998, 1987, 1985, 2002, 2007, 1997, 2004])

# %%
test['Outlet_Establishment_Year'].unique()
# Out:
# array([1999, 2007, 1998, 1985, 1997, 2009, 2002, 1987, 2004])

# %%
test['Item_Identifier'].str[:2].unique()
# Out:
# array(['FD', 'NC', 'DR'], dtype=object)

# %%
len(train['Item_MRP'].unique())
# Out:
# 5938

# %%
len(test['Item_MRP'].unique())
# Out:
# 4402

# %%
train['Item']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Item'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-977269220.py in <cell line: 0>()
# ----> 1 train['Item']
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Item'

# %%
# Combine (key allows easy split back)
if test is not None:
    combined = pd.concat({'train': train, 'test': test}, axis=0, sort=False).reset_index(level=0).rename(columns={'level_0':'_split'})
else:
    combined = train.copy()
    combined['_split'] = 'train'

combined.head(3)
# Out:
#   _split Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0  train           FDA15         9.30          Low Fat         0.016047
# 1  train           DRC01         5.92          Regular         0.019278
# 2  train           FDN15        17.50          Low Fat         0.016760
#
#      Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0        Dairy  249.8092            OUT049                       1999
# 1  Soft Drinks   48.2692            OUT018                       2009
# 2         Meat  141.6180            OUT049                       1999
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# 1      Medium               Tier 3  Supermarket Type2           443.4228
# 2      Medium               Tier 1  Supermarket Type1          2097.2700

# %% [markdown]
# ## Utils

# %%
def normalize_fat(x):
  mapping = {'LF':'Low Fat','low fat':'Low Fat','Low Fat':'Low Fat','reg':'Regular',
            'Regular':'Regular'}
  return x.replace(mapping)

def clean_data(df):

  if 'Item_Visibility' in df.columns:
    vis = df['Item_Visibility'].replace(0,np.nan)
    med_per_item = vis.groupby(df['Item_Identifier']).transform('median')
    df['Item_Visibility'] = np.where(df['Item_Visibility']==0,med_per_item,df['Item_Visibility'])
    # For remaining nans
    df['Item_Visibility'] = df['Item_Visibility'].fillna(df['Item_Visibility'].median())

  if 'Item_Weight' in df.columns:
    mean_per_item = df.groupby('Item_Identifier')['Item_Weight'].transform('mean')
    df['Item_Weight'] = df['Item_Weight'].fillna(mean_per_item)
    df['Item_Weight'] = df['Item_Weight'].fillna(df['Item_Weight'].median())

  if 'Outlet_Size' in df.columns and 'Outlet_Type' in df.columns:
    mode_map = df.groupby('Outlet_Type')['Outlet_Size'].apply(lambda s:s.value_counts().idxmax())
    # Fallback
    global_mode = df['Outlet_Size'].value_counts().idxmax()
    df['Outlet_Size'] = df['Outlet_Size'].fillna(df['Outlet_Type'].map(mode_map)).fillna(global_mode)

  # Outlet_Age
  if 'Outlet_Establishment_Year' in df.columns:
      df['Outlet_Age'] = 2013 - df['Outlet_Establishment_Year']

  # Item_Category
  if 'Item_Identifier' in df.columns:
      df['Item_Category'] = df['Item_Identifier'].astype(str).str[:2]

  # Visibility Mean Ratio per item
  if {'Item_Visibility','Item_Identifier'}.issubset(df.columns):
    item_mean = df.groupby('Item_Identifier')['Item_Visibility'].transform('mean')
    df['Visibility_MeanRatio'] = df['Item_Visibility']/ item_mean
    df['Visibility_MeanRatio'] = df['Visibility_MeanRatio'].replace([np.inf,-np.inf],np.nan).fillna(1.0)

  if 'Item_MRP' in df.columns:
    try:
      df['MRP_bin'] = pd.qcut(df['Item_MRP'],4,labels = ['Low','Medium','High','Very High'])
    except:
      df['MRP_bin'] = 'Medium'

  # Promotion proxy
  if 'Item_Visibility' in df.columns:
    thr = df['Item_Visibility'].quantile(0.9)
    df['High_Visibility_Flag'] = (df['Item_Visibility']>thr).astype(int)

  #  Interaction : MRP X Outlet_Type
  if {'Item_MRP','Outlet_Type'}.issubset(df.columns):
    outlet_type_codes = df['Outlet_Type'].astype('category').cat.codes
    df['MRP_OutletType'] = df['Item_MRP'] * outlet_type_codes

  # Outlet clustering : encoding three columns
  if {'Outlet_Size','Outlet_Type','Outlet_Location_Type'}.issubset(df.columns):
    tmp = df[['Outlet_Size','Outlet_Type','Outlet_Location_Type']].astype(str).copy()
    for c in tmp.columns:
      le = LabelEncoder()
      tmp[c] = le.fit_transform(tmp[c])
    kmeans = KMeans(n_clusters = 4,random_state = 42,n_init=10)
  return df

clean_df = clean_data(combined)

# %%
clean_df.shape
# Out:
# (14204, 19)

# %%
if 'Item_Outlet_Sales' not in clean_df.columns:
    raise KeyError("Target 'Item_Outlet_Sales' must be in train.")

train_fe = clean_df[clean_df['_split']=='train'].drop(columns=['_split']).copy()
test_fe  = clean_df[clean_df['_split']=='test'].drop(columns=['_split']).copy() if 'test' in clean_df['_split'].values else None

print(train_fe.shape, getattr(test_fe, 'shape', None))
# Out:
# (8523, 18) (5681, 18)

# %%
def oof_target_encode(train_df, test_df, col, target, n_splits=5, alpha=10, random_state=42):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    te_train = pd.Series(index=train_df.index, dtype=float)
    global_mean = train_df[target].mean()

    for tr_idx, va_idx in kf.split(train_df):
        tr, va = train_df.iloc[tr_idx], train_df.iloc[va_idx]
        stats = tr.groupby(col)[target].agg(['mean','count'])
        stats['te'] = (stats['count']*stats['mean'] + alpha*global_mean) / (stats['count'] + alpha)
        mapping = stats['te']
        te_train.iloc[va_idx] = train_df.iloc[va_idx][col].map(mapping).fillna(global_mean)

    full_stats = train_df.groupby(col)[target].agg(['mean','count'])
    full_stats['te'] = (full_stats['count']*full_stats['mean'] + alpha*global_mean) / (full_stats['count'] + alpha)
    full_mapping = full_stats['te']

    te_test = None
    if test_df is not None:
        te_test = test_df[col].map(full_mapping).fillna(global_mean)

    return te_train.astype(float), (te_test.astype(float) if te_test is not None else None)

target_col = 'Item_Outlet_Sales'
te_cols = ['Outlet_Type','Item_Type','Outlet_Identifier','Item_Category']
for c in te_cols:
    if c in train_fe.columns:
        tr_te, te_te = oof_target_encode(train_fe, test_fe, c, target_col, n_splits=5, alpha=10)
        train_fe[c+'_TE'] = tr_te
        if test_fe is not None:
            test_fe[c+'_TE'] = te_te

print("OOF TE added:", [c+'_TE' for c in te_cols if c in train_fe.columns])
# Out:
# OOF TE added: ['Outlet_Type_TE', 'Item_Type_TE', 'Outlet_Identifier_TE', 'Item_Category_TE']

# %%
TARGET = 'Item_Outlet_Sales'
y = np.log1p(train_fe[TARGET].values)

X = train_fe.drop(columns=[TARGET])
X_test = test_fe.copy() if test_fe is not None else None

num_cols = X.select_dtypes(include=[np.number]).columns.tolist()
cat_cols = X.select_dtypes(exclude=[np.number]).columns.tolist()

print("Numeric:", len(num_cols), "| Categorical:", len(cat_cols))

numeric_transformer = Pipeline(steps=[('imputer', SimpleImputer(strategy='median'))])
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ohe', OneHotEncoder(handle_unknown='ignore'))
])

preprocess = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, num_cols),
        ('cat', categorical_transformer, cat_cols)
    ]
)

groups = train_fe['Outlet_Identifier'].values if 'Outlet_Identifier' in train_fe.columns else None
# Out:
# Numeric: 12 | Categorical: 9

# %%
def cv_rmse(model, X, y, preprocess, groups=None, n_splits=5, random_state=42):
    if groups is not None:
        kf = GroupKFold(n_splits=n_splits)
        splits = kf.split(X, y, groups)
    else:
        kf = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)
        splits = kf.split(X, y)
    scores = []
    for tr, va in splits:
        X_tr, X_va = X.iloc[tr], X.iloc[va]
        y_tr, y_va = y[tr], y[va]
        pipe = Pipeline([('prep', preprocess), ('model', model)])
        pipe.fit(X_tr, y_tr)
        y_hat = pipe.predict(X_va)
        rmse = mean_squared_error(y_va, y_hat)
        scores.append(rmse)
    return float(np.mean(scores)), float(np.std(scores))

models = {
    "LinearRegression": LinearRegression(),
    "RidgeCV": RidgeCV(alphas=np.logspace(-3,3,20)),
    "RandomForest": RandomForestRegressor(n_estimators=400, random_state=42, n_jobs=-1),
    "XGBoost": XGBRegressor(n_estimators=800, learning_rate=0.05, max_depth=6,
                             subsample=0.8, colsample_bytree=0.8, random_state=42, tree_method="hist"),
    "LightGBM": LGBMRegressor(n_estimators=1000, learning_rate=0.05, subsample=0.8,
                               colsample_bytree=0.8, random_state=42, n_jobs=-1)
}

results = {}
for name, model in models.items():
    mean_rmse, std_rmse = cv_rmse(model, X, y, preprocess, groups=groups, n_splits=5)
    results[name] = (mean_rmse, std_rmse)
    print(f"{name:15s} | CV RMSE (log-target): {mean_rmse:.4f} ± {std_rmse:.4f}")
# Out:
# LinearRegression | CV RMSE (log-target): 0.4671 ± 0.1297
# RidgeCV         | CV RMSE (log-target): 0.3641 ± 0.0782
# RandomForest    | CV RMSE (log-target): 0.4025 ± 0.1195
# XGBoost         | CV RMSE (log-target): 0.3433 ± 0.0615
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000919 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1517
# [LightGBM] [Info] Number of data points in the train set: 7060, number of used features: 57
# [LightGBM] [Info] Start training from score 7.331234
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000737 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1520
# [LightGBM] [Info] Number of data points in the train set: 7036, number of used features: 57
# [LightGBM] [Info] Start training from score 7.412878
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000680 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1519
# [LightGBM] [Info] Number of data points in the train set: 6664, number of used features: 58
# [LightGBM] [Info] Start training from score 7.247280
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000788 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1515
# [LightGBM] [Info] Number of data points in the train set: 6665, number of used features: 57
# [LightGBM] [Info] Start training from score 7.260624
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000677 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1522
# [LightGBM] [Info] Number of data points in the train set: 6667, number of used features: 58
# [LightGBM] [Info] Start training from score 7.228934
# LightGBM        | CV RMSE (log-target): 0.3740 ± 0.0543

# %%
best_name = min(results, key=lambda k: results[k][0])
print("Best model:", best_name, "->", results[best_name])

best_model = models[best_name]
final_pipe = Pipeline([('prep', preprocess), ('model', best_model)])
final_pipe.fit(X, y)

# Back-transform to original scale for a sense of fit quality (not generalization!)
train_pred_log = final_pipe.predict(X)
train_pred = np.expm1(train_pred_log)
true = train_fe[TARGET].values
train_rmse = mean_squared_error(true, train_pred)
print(f"Train RMSE (original scale): {train_rmse:.2f}")

if X_test is not None:
    test_pred_log = final_pipe.predict(X_test)
    test_pred = np.expm1(test_pred_log)
    sub_cols = [c for c in ['Item_Identifier','Outlet_Identifier'] if c in X_test.columns]
    submission = pd.DataFrame({**{c: X_test[c].values for c in sub_cols}, TARGET: test_pred})
    submission.to_csv('submission.csv', index=False)
    print("Saved submission.csv")
else:
    print("Test not provided; skipping submission.")
# Out:
# Best model: XGBoost -> (0.34329832807839594, 0.06148430956171311)
# Train RMSE (original scale): 921154.31
# Saved submission.csv

# %% [markdown]
# # Tuning

# %%
# --- Hyperparameter tuning for XGBoost with GroupKFold ---

from xgboost import XGBRegressor
from sklearn.model_selection import RandomizedSearchCV, GroupKFold
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
import numpy as np
import warnings

# Safety checks (assumes you already have X, y, preprocess, groups, X_test, test, TARGET)
assert 'preprocess' in globals(), "preprocess (ColumnTransformer) not found"
assert 'X' in globals() and 'y' in globals(), "X/y not found"
assert 'groups' in globals(), "groups not found (use Outlet_Identifier)"
assert 'TARGET' in globals(), "TARGET not found"

# %%
# Try to use neg_root_mean_squared_error; fallback if unsupported
scorer = 'neg_root_mean_squared_error'
try:
    from sklearn.metrics import get_scorer
    _ = get_scorer(scorer)
except Exception:
    warnings.warn("neg_root_mean_squared_error not available; using neg_mean_squared_error")
    scorer = 'neg_mean_squared_error'

xgb_base = XGBRegressor(
    objective='reg:squarederror',
    random_state=42,
    n_jobs=-1,
    tree_method='hist'  # fast + stable
)

pipe = Pipeline([
    ('prep', preprocess),
    ('model', xgb_base)
])

param_dist = {
    'model__n_estimators':      [600, 800, 1000, 1200, 1500],
    'model__learning_rate':     [0.02, 0.03, 0.05, 0.07, 0.1],
    'model__max_depth':         [3, 4, 5, 6, 7, 8],
    'model__min_child_weight':  [1, 2, 3, 5, 7, 10],
    'model__subsample':         [0.6, 0.7, 0.8, 0.9, 1.0],
    'model__colsample_bytree':  [0.6, 0.7, 0.8, 0.9, 1.0],
    'model__reg_alpha':         [0.0, 1e-3, 1e-2, 1e-1, 1.0],
    'model__reg_lambda':        [0.1, 0.5, 1.0, 2.0, 5.0, 10.0],
    'model__gamma':             [0.0, 0.1, 0.3, 0.5]
}

cv = GroupKFold(n_splits=5)

search = RandomizedSearchCV(
    estimator=pipe,
    param_distributions=param_dist,
    n_iter=50,                 # increase to 100+ if you want to search deeper
    scoring=scorer,
    cv=cv,
    verbose=1,
    n_jobs=-1,
    random_state=42,
    refit=True                 # refit on full data using the best params
)

search.fit(X, y, **({'groups': groups} if groups is not None else {}))

best_pipe = search.best_estimator_
best_params = search.best_params_
best_score = search.best_score_

# Convert score to RMSE (positive) for readability
if scorer == 'neg_root_mean_squared_error':
    cv_rmse = -best_score
else:
    cv_rmse = np.sqrt(-best_score)

print("\n=== XGBoost best params ===")
for k, v in best_params.items():
    print(f"{k}: {v}")
print(f"CV RMSE (log-target): {cv_rmse:.4f}")

# Fit on all training data (already done by refit=True, but we can be explicit)
best_pipe.fit(X, y)

# Train fit quality on original scale (informational only)
train_pred_log = best_pipe.predict(X)
train_pred = np.expm1(train_pred_log)
true = np.expm1(y)  # if y was log1p already; else use train[TARGET].values
mse_train = mean_squared_error(true, train_pred)
train_rmse = np.sqrt(mse_train)
print(f"Train RMSE (original scale): {train_rmse:.2f}")
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
#
# === XGBoost best params ===
# model__subsample: 0.9
# model__reg_lambda: 10.0
# model__reg_alpha: 0.0
# model__n_estimators: 800
# model__min_child_weight: 3
# model__max_depth: 6
# model__learning_rate: 0.1
# model__gamma: 0.5
# model__colsample_bytree: 0.6
# CV RMSE (log-target): 0.5493
# Train RMSE (original scale): 1010.45

# %%
# Predict test and save submission if you have test
if 'X_test' in globals() and X_test is not None and 'test' in globals():
    test_pred_log = best_pipe.predict(X_test)
    test_pred = np.expm1(test_pred_log)

    id_cols = [c for c in ['Item_Identifier','Outlet_Identifier'] if c in X_test.columns]
    submission = __import__('pandas').DataFrame({**{c: X_test[c].values for c in id_cols},
                                                 TARGET: test_pred})
    submission.to_csv('submission_updated.csv', index=False)
    print("Saved submission.csv")
# Out:
# Saved submission.csv

# %% [markdown]
# # Optuna

# %%
# !pip -q install optuna
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.4/247.4 kB 16.5 MB/s eta 0:00:00

# %%
# ---- Optuna hyperparameter tuning for XGBoost (GroupKFold, log-RMSE) ----
# Assumes X, y, preprocess, groups, X_test, test, TARGET are already defined.

import optuna
from optuna.samplers import TPESampler
import numpy as np
from sklearn.model_selection import GroupKFold
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
from xgboost import XGBRegressor

def cv_rmse_logtarget(model, X, y, preprocess, groups, n_splits=5):
    kf = GroupKFold(n_splits=n_splits)
    rmses = []
    for tr_idx, va_idx in kf.split(X, y, groups):
        X_tr, X_va = X.iloc[tr_idx], X.iloc[va_idx]
        y_tr, y_va = y[tr_idx], y[va_idx]
        pipe = Pipeline([('prep', preprocess), ('model', model)])
        pipe.fit(X_tr, y_tr)
        y_hat = pipe.predict(X_va)
        rmse = np.sqrt(mean_squared_error(y_va, y_hat))
        rmses.append(rmse)
    return float(np.mean(rmses)), float(np.std(rmses))

def objective(trial: optuna.Trial):
    params = {
        'objective': 'reg:squarederror',
        'tree_method': 'hist',
        'random_state': 42,
        'n_jobs': -1,

        # SEARCH SPACE (lower bounds > 0 where log=True)
        'n_estimators':     trial.suggest_int('n_estimators', 600, 1800),
        'learning_rate':    trial.suggest_float('learning_rate', 0.02, 0.12, log=True),
        'max_depth':        trial.suggest_int('max_depth', 4, 9),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 8),
        'subsample':        trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'gamma':            trial.suggest_float('gamma', 0.0, 0.6),           # not log
        'reg_alpha':        trial.suggest_float('reg_alpha', 1e-8, 1.0, log=True),  # FIXED (>0)
        'reg_lambda':       trial.suggest_float('reg_lambda', 1e-3, 50.0, log=True) # >0
    }

    model = XGBRegressor(**params)
    mean_rmse, std_rmse = cv_rmse_logtarget(model, X, y, preprocess, groups, n_splits=5)
    trial.set_user_attr('cv_std', std_rmse)
    return mean_rmse   # Optuna minimizes

study = optuna.create_study(direction='minimize', sampler=TPESampler(seed=42),
                            study_name='xgb_bigmart_logrmse_fixed')
n_trials = 200  # increase if you can
print(f"Running Optuna with {n_trials} trials…")
study.optimize(objective, n_trials=n_trials, show_progress_bar=True)

print("\n=== Best trial ===")
print(f"Value (CV RMSE log-target): {study.best_value:.4f}")
for k, v in study.best_params.items():
    print(f"{k}: {v}")
print(f"CV RMSE std (best trial): {study.best_trial.user_attrs.get('cv_std'):.4f}")
# Out:
# [I 2025-08-31 14:38:15,519] A new study created in memory with name: xgb_bigmart_logrmse_fixed
# Running Optuna with 200 trials…
#   0%|          | 0/200 [00:00<?, ?it/s]
# [I 2025-08-31 14:38:44,295] Trial 0 finished with value: 0.6191216133504669 and parameters: {'n_estimators': 1049, 'learning_rate': 0.10985745201142037, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.6624074561769746, 'colsample_bytree': 0.662397808134481, 'gamma': 0.03485016730091967, 'reg_alpha': 0.08499808989182997, 'reg_lambda': 0.6677615511747083}. Best is trial 0 with value: 0.6191216133504669.
# [I 2025-08-31 14:39:47,716] Trial 1 finished with value: 0.5909728168100898 and parameters: {'n_estimators': 1450, 'learning_rate': 0.020751421204777677, 'max_depth': 9, 'min_child_weight': 7, 'subsample': 0.6849356442713105, 'colsample_bytree': 0.6727299868828402, 'gamma': 0.11004270591206029, 'reg_alpha': 2.716051144654844e-06, 'reg_lambda': 0.2922905212920093}. Best is trial 1 with value: 0.5909728168100898.
# [I 2025-08-31 14:40:12,187] Trial 2 finished with value: 0.5806021603182601 and parameters: {'n_estimators': 1118, 'learning_rate': 0.03370158413473581, 'max_depth': 7, 'min_child_weight': 2, 'subsample': 0.7168578594140873, 'colsample_bytree': 0.7465447373174767, 'gamma': 0.27364199053022153, 'reg_alpha': 0.019116469627784252, 'reg_lambda': 0.008674832802525461}. Best is trial 2 with value: 0.5806021603182601.
# [I 2025-08-31 14:40:21,467] Trial 3 finished with value: 0.5597106287645844 and parameters: {'n_estimators': 1217, 'learning_rate': 0.057812018524968964, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.6682096494749166, 'colsample_bytree': 0.6260206371941118, 'gamma': 0.5693313223519999, 'reg_alpha': 0.530953226900921, 'reg_lambda': 6.289771819487036}. Best is trial 3 with value: 0.5597106287645844.
# [I 2025-08-31 14:41:10,315] Trial 4 finished with value: 0.5985819637444638 and parameters: {'n_estimators': 965, 'learning_rate': 0.023825041912123594, 'max_depth': 8, 'min_child_weight': 4, 'subsample': 0.6488152939379115, 'colsample_bytree': 0.798070764044508, 'gamma': 0.020633112669131037, 'reg_alpha': 0.1881755597772026, 'reg_lambda': 0.016443693426189242}. Best is trial 3 with value: 0.5597106287645844.
# [I 2025-08-31 14:41:32,102] Trial 5 finished with value: 0.6041444428745183 and parameters: {'n_estimators': 1395, 'learning_rate': 0.03496136329223948, 'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.6739417822102108, 'colsample_bytree': 0.9878338511058234, 'gamma': 0.4650796940166687, 'reg_alpha': 0.32808889626606236, 'reg_lambda': 16.023850290194936}. Best is trial 3 with value: 0.5597106287645844.
# [I 2025-08-31 14:41:50,995] Trial 6 finished with value: 0.6085440728578052 and parameters: {'n_estimators': 1318, 'learning_rate': 0.10432480565485087, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.6180909155642152, 'colsample_bytree': 0.7301321323053057, 'gamma': 0.2332063738136892, 'reg_alpha': 1.481809088646707e-06, 'reg_lambda': 7.838134236608707}. Best is trial 3 with value: 0.5597106287645844.
# [I 2025-08-31 14:42:03,531] Trial 7 finished with value: 0.5665657880795395 and parameters: {'n_estimators': 1028, 'learning_rate': 0.033085639673402445, 'max_depth': 7, 'min_child_weight': 2, 'subsample': 0.9208787923016158, 'colsample_bytree': 0.6298202574719083, 'gamma': 0.5921321619603104, 'reg_alpha': 0.015064619068942013, 'reg_lambda': 0.008585370205937366}. Best is trial 3 with value: 0.5597106287645844.
# [I 2025-08-31 14:42:10,521] Trial 8 finished with value: 0.5685524893404167 and parameters: {'n_estimators': 606, 'learning_rate': 0.08621489941526675, 'max_depth': 8, 'min_child_weight': 6, 'subsample': 0.9085081386743783, 'colsample_bytree': 0.6296178606936361, 'gamma': 0.21507943712656355, 'reg_alpha': 8.451863533931625e-08, 'reg_lambda': 11.368341439732731}. Best is trial 3 with value: 0.5597106287645844.
# [I 2025-08-31 14:42:27,730] Trial 9 finished with value: 0.5817350058556657 and parameters: {'n_estimators': 1348, 'learning_rate': 0.03618417769126916, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.7300733288106989, 'colsample_bytree': 0.8918424713352255, 'gamma': 0.38253448281312785, 'reg_alpha': 0.12522814303053625, 'reg_lambda': 0.16554793541373172}. Best is trial 3 with value: 0.5597106287645844.
# [I 2025-08-31 14:42:37,939] Trial 10 finished with value: 0.5768647284293313 and parameters: {'n_estimators': 1735, 'learning_rate': 0.06408972481105049, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.8076576013037925, 'colsample_bytree': 0.876098829427658, 'gamma': 0.5838501428924083, 'reg_alpha': 0.0006299775810019788, 'reg_lambda': 1.2352207288584414}. Best is trial 3 with value: 0.5597106287645844.
# [I 2025-08-31 14:42:45,164] Trial 11 finished with value: 0.5609718001085027 and parameters: {'n_estimators': 782, 'learning_rate': 0.052043480764212884, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.95621601194762, 'colsample_bytree': 0.6123850196223547, 'gamma': 0.5816708087347191, 'reg_alpha': 0.0007202349503619245, 'reg_lambda': 0.001102561530234474}. Best is trial 3 with value: 0.5597106287645844.
# [I 2025-08-31 14:42:53,418] Trial 12 finished with value: 0.5586679215238731 and parameters: {'n_estimators': 774, 'learning_rate': 0.05603583720162585, 'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.9978494133549762, 'colsample_bytree': 0.7097939893129923, 'gamma': 0.4631544074280427, 'reg_alpha': 0.000568534770435637, 'reg_lambda': 0.0010652180617334497}. Best is trial 12 with value: 0.5586679215238731.
# [I 2025-08-31 14:42:59,171] Trial 13 finished with value: 0.5603226611852117 and parameters: {'n_estimators': 783, 'learning_rate': 0.06421237849147013, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.8254017284107714, 'colsample_bytree': 0.7162035957864589, 'gamma': 0.47173378529577054, 'reg_alpha': 7.077498354609843e-05, 'reg_lambda': 42.73757087256832}. Best is trial 12 with value: 0.5586679215238731.
# [I 2025-08-31 14:43:07,692] Trial 14 finished with value: 0.5581900069411803 and parameters: {'n_estimators': 1663, 'learning_rate': 0.049694471976791096, 'max_depth': 5, 'min_child_weight': 6, 'subsample': 0.9996048321042734, 'colsample_bytree': 0.7959968024356568, 'gamma': 0.4717651489440391, 'reg_alpha': 3.4864252542278224e-05, 'reg_lambda': 0.05491174035964442}. Best is trial 14 with value: 0.5581900069411803.
# [I 2025-08-31 14:43:15,789] Trial 15 finished with value: 0.5625141724618377 and parameters: {'n_estimators': 1756, 'learning_rate': 0.08094130576969902, 'max_depth': 5, 'min_child_weight': 7, 'subsample': 0.9895023471012536, 'colsample_bytree': 0.8129081443445456, 'gamma': 0.3782413309946188, 'reg_alpha': 8.397990964160307e-06, 'reg_lambda': 0.0014293421296130593}. Best is trial 14 with value: 0.5581900069411803.
# [I 2025-08-31 14:43:26,907] Trial 16 finished with value: 0.5743118442266291 and parameters: {'n_estimators': 1575, 'learning_rate': 0.04371599551649701, 'max_depth': 6, 'min_child_weight': 6, 'subsample': 0.8642396983313834, 'colsample_bytree': 0.8064114554738083, 'gamma': 0.44058645419969955, 'reg_alpha': 0.00029986594356080703, 'reg_lambda': 0.048313132626022}. Best is trial 14 with value: 0.5581900069411803.
# [I 2025-08-31 14:43:46,015] Trial 17 finished with value: 0.5839022927377424 and parameters: {'n_estimators': 1592, 'learning_rate': 0.04376011598388758, 'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.9750026893760447, 'colsample_bytree': 0.8604035330355403, 'gamma': 0.3764518959689805, 'reg_alpha': 1.9518143463535143e-08, 'reg_lambda': 0.0031641160046663452}. Best is trial 14 with value: 0.5581900069411803.
# [I 2025-08-31 14:43:55,116] Trial 18 finished with value: 0.569750826935848 and parameters: {'n_estimators': 865, 'learning_rate': 0.07167404659781247, 'max_depth': 6, 'min_child_weight': 3, 'subsample': 0.9276269504938004, 'colsample_bytree': 0.7655786947751761, 'gamma': 0.5218960809563722, 'reg_alpha': 3.1490955346510016e-05, 'reg_lambda': 0.04813789802205533}. Best is trial 14 with value: 0.5581900069411803.
# [I 2025-08-31 14:44:01,932] Trial 19 finished with value: 0.5884892086784349 and parameters: {'n_estimators': 654, 'learning_rate': 0.0489786206540538, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.8798993512408098, 'colsample_bytree': 0.9505516551557487, 'gamma': 0.3255463923276219, 'reg_alpha': 0.0022623615799611356, 'reg_lambda': 0.05624228826824646}. Best is trial 14 with value: 0.5581900069411803.
# [I 2025-08-31 14:44:08,921] Trial 20 finished with value: 0.5567703101319973 and parameters: {'n_estimators': 1219, 'learning_rate': 0.027253389101167536, 'max_depth': 4, 'min_child_weight': 6, 'subsample': 0.9996164842794727, 'colsample_bytree': 0.6960313971494949, 'gamma': 0.5050877172912707, 'reg_alpha': 4.270969992991555e-07, 'reg_lambda': 2.3326062854517957}. Best is trial 20 with value: 0.5567703101319973.
# [I 2025-08-31 14:44:14,356] Trial 21 finished with value: 0.5536006958373851 and parameters: {'n_estimators': 1205, 'learning_rate': 0.026799952905193516, 'max_depth': 4, 'min_child_weight': 6, 'subsample': 0.9977132063671227, 'colsample_bytree': 0.6861878595056962, 'gamma': 0.5298682070442122, 'reg_alpha': 8.492379594517325e-08, 'reg_lambda': 2.1625333502537623}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:44:22,156] Trial 22 finished with value: 0.5583767412486187 and parameters: {'n_estimators': 1200, 'learning_rate': 0.02749455942966606, 'max_depth': 4, 'min_child_weight': 6, 'subsample': 0.9385277650054572, 'colsample_bytree': 0.6849758401122592, 'gamma': 0.5068324568291753, 'reg_alpha': 1.77449395571933e-07, 'reg_lambda': 1.4573207601758047}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:44:30,516] Trial 23 finished with value: 0.5583251909701129 and parameters: {'n_estimators': 1520, 'learning_rate': 0.027822721672066963, 'max_depth': 4, 'min_child_weight': 7, 'subsample': 0.9613481659415247, 'colsample_bytree': 0.7621427023670798, 'gamma': 0.527873855498025, 'reg_alpha': 5.55401632399693e-07, 'reg_lambda': 3.253989596038724}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:44:39,509] Trial 24 finished with value: 0.5601671369136997 and parameters: {'n_estimators': 1260, 'learning_rate': 0.0207116951007249, 'max_depth': 4, 'min_child_weight': 6, 'subsample': 0.8903771405379148, 'colsample_bytree': 0.6877152992001893, 'gamma': 0.41898140487248065, 'reg_alpha': 1.4412856642655413e-08, 'reg_lambda': 0.29963373976938334}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:44:50,463] Trial 25 finished with value: 0.5713616064952032 and parameters: {'n_estimators': 1657, 'learning_rate': 0.02827798021283213, 'max_depth': 4, 'min_child_weight': 7, 'subsample': 0.834799059420789, 'colsample_bytree': 0.8481605233723446, 'gamma': 0.5397510799263427, 'reg_alpha': 1.0560103869449096e-07, 'reg_lambda': 1.983311090240782}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:44:59,593] Trial 26 finished with value: 0.5612465787559561 and parameters: {'n_estimators': 1453, 'learning_rate': 0.04048163317825746, 'max_depth': 5, 'min_child_weight': 6, 'subsample': 0.9944724925931318, 'colsample_bytree': 0.7860941529006004, 'gamma': 0.3252772202318977, 'reg_alpha': 1.8981162753417046e-05, 'reg_lambda': 0.13791657088844975}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:45:11,833] Trial 27 finished with value: 0.5682794322165737 and parameters: {'n_estimators': 1120, 'learning_rate': 0.023882298634586255, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.9511195914440795, 'colsample_bytree': 0.8334113000939729, 'gamma': 0.4933080385104428, 'reg_alpha': 4.7248303463987267e-07, 'reg_lambda': 0.648100600853068}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:45:22,228] Trial 28 finished with value: 0.5741086428199994 and parameters: {'n_estimators': 917, 'learning_rate': 0.030702274080830354, 'max_depth': 4, 'min_child_weight': 8, 'subsample': 0.7828436536165114, 'colsample_bytree': 0.9056296567827691, 'gamma': 0.4209592040329193, 'reg_alpha': 4.614108844076556e-06, 'reg_lambda': 24.835351685105756}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:45:33,080] Trial 29 finished with value: 0.5621387400699488 and parameters: {'n_estimators': 1152, 'learning_rate': 0.039728654223871104, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.7672975738414405, 'colsample_bytree': 0.6489583520863897, 'gamma': 0.5454689916098081, 'reg_alpha': 7.993343526944668e-07, 'reg_lambda': 0.6059054599058169}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:45:42,516] Trial 30 finished with value: 0.5575375229009059 and parameters: {'n_estimators': 1047, 'learning_rate': 0.023268453173442113, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.9678381778758314, 'colsample_bytree': 0.6687494468844493, 'gamma': 0.07386560505124057, 'reg_alpha': 3.28993801772517e-08, 'reg_lambda': 2.753303819315925}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:45:51,572] Trial 31 finished with value: 0.557680411171316 and parameters: {'n_estimators': 1031, 'learning_rate': 0.02408190437041555, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.970430748853343, 'colsample_bytree': 0.665504839351039, 'gamma': 0.08376531270155012, 'reg_alpha': 4.546462298210447e-08, 'reg_lambda': 3.69649826380569}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:46:01,617] Trial 32 finished with value: 0.5563287459458435 and parameters: {'n_estimators': 1021, 'learning_rate': 0.02419228623780806, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.972487849782955, 'colsample_bytree': 0.6699224497432729, 'gamma': 0.08732400647766235, 'reg_alpha': 3.8519753518942995e-08, 'reg_lambda': 3.462752934177424}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:46:12,835] Trial 33 finished with value: 0.5584418687752909 and parameters: {'n_estimators': 1077, 'learning_rate': 0.0200820679094773, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.9037445525698348, 'colsample_bytree': 0.7008079243379188, 'gamma': 0.15357050164322356, 'reg_alpha': 3.3003366333446046e-08, 'reg_lambda': 3.4087572377299824}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:46:25,353] Trial 34 finished with value: 0.5660839637272874 and parameters: {'n_estimators': 1236, 'learning_rate': 0.025173361240086303, 'max_depth': 4, 'min_child_weight': 7, 'subsample': 0.9706878240600181, 'colsample_bytree': 0.6495815281598429, 'gamma': 0.09109774743043746, 'reg_alpha': 2.454960610043765e-07, 'reg_lambda': 0.9870648425697663}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:46:36,212] Trial 35 finished with value: 0.5600264505401196 and parameters: {'n_estimators': 972, 'learning_rate': 0.02199317851744183, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.9325178012494975, 'colsample_bytree': 0.7342596173139949, 'gamma': 0.15404038570814815, 'reg_alpha': 1.249936994576715e-08, 'reg_lambda': 6.053048436125153}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:47:28,403] Trial 36 finished with value: 0.5919389212757138 and parameters: {'n_estimators': 1174, 'learning_rate': 0.02604827583641783, 'max_depth': 9, 'min_child_weight': 5, 'subsample': 0.8502776009082994, 'colsample_bytree': 0.6670012117515498, 'gamma': 0.0025615149790242375, 'reg_alpha': 4.7555775264400226e-08, 'reg_lambda': 0.47723614713615403}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:47:42,397] Trial 37 finished with value: 0.5568594855601305 and parameters: {'n_estimators': 1284, 'learning_rate': 0.022844866695420435, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.9434826681651919, 'colsample_bytree': 0.6910950336995509, 'gamma': 0.05147178856524695, 'reg_alpha': 1.397174823866165e-06, 'reg_lambda': 14.909904024183653}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:47:59,401] Trial 38 finished with value: 0.5670277348892885 and parameters: {'n_estimators': 1293, 'learning_rate': 0.030744153058109788, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.9376757719858353, 'colsample_bytree': 0.7544853103940043, 'gamma': 0.05450415285957364, 'reg_alpha': 2.3315815980852532e-06, 'reg_lambda': 27.349483742285162}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:48:17,492] Trial 39 finished with value: 0.5622313594249306 and parameters: {'n_estimators': 1435, 'learning_rate': 0.03017693414924492, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.9085421966773642, 'colsample_bytree': 0.6008712844066347, 'gamma': 0.1618888068826746, 'reg_alpha': 1.3134450006493947e-06, 'reg_lambda': 12.507818083175207}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:48:42,956] Trial 40 finished with value: 0.5658211164722708 and parameters: {'n_estimators': 1292, 'learning_rate': 0.022350717565310083, 'max_depth': 8, 'min_child_weight': 3, 'subsample': 0.9826367060651677, 'colsample_bytree': 0.7272936411614412, 'gamma': 0.21916817015183038, 'reg_alpha': 2.4423349794744785e-07, 'reg_lambda': 4.898425077804858}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:48:54,238] Trial 41 finished with value: 0.5568783967822325 and parameters: {'n_estimators': 1096, 'learning_rate': 0.02250481702578669, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.9517268481987088, 'colsample_bytree': 0.6893559226742414, 'gamma': 0.04012749244944695, 'reg_alpha': 1.231198039060634e-07, 'reg_lambda': 8.957711157491303}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:49:07,816] Trial 42 finished with value: 0.5611965087252049 and parameters: {'n_estimators': 1359, 'learning_rate': 0.02627364765311058, 'max_depth': 4, 'min_child_weight': 6, 'subsample': 0.9501284016721718, 'colsample_bytree': 0.6860388526392814, 'gamma': 0.12390532330542622, 'reg_alpha': 1.1117987496079295e-07, 'reg_lambda': 8.935965420700867}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:49:19,406] Trial 43 finished with value: 0.5574100512709212 and parameters: {'n_estimators': 1088, 'learning_rate': 0.0215882002612418, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.920084872702456, 'colsample_bytree': 0.6415063530804078, 'gamma': 0.031425463102432244, 'reg_alpha': 3.4622019650309994e-07, 'reg_lambda': 17.185440066941155}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:49:35,308] Trial 44 finished with value: 0.5675616524971296 and parameters: {'n_estimators': 1141, 'learning_rate': 0.03318557911061827, 'max_depth': 7, 'min_child_weight': 4, 'subsample': 0.9499969821902207, 'colsample_bytree': 0.7000189496717736, 'gamma': 0.26706758952842613, 'reg_alpha': 8.576227492132126e-06, 'reg_lambda': 1.9574264324151491}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:49:45,535] Trial 45 finished with value: 0.5607463554462531 and parameters: {'n_estimators': 985, 'learning_rate': 0.036010932880566025, 'max_depth': 4, 'min_child_weight': 6, 'subsample': 0.978343525560588, 'colsample_bytree': 0.7213811130824325, 'gamma': 0.05124761304184072, 'reg_alpha': 1.0914144446504558e-06, 'reg_lambda': 6.70918329358385}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:50:06,733] Trial 46 finished with value: 0.5650316498667323 and parameters: {'n_estimators': 1213, 'learning_rate': 0.024757164001552583, 'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.614316728017922, 'colsample_bytree': 0.6218239555275137, 'gamma': 0.11571630941151459, 'reg_alpha': 7.73220050469992e-08, 'reg_lambda': 33.369815093930995}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:50:19,554] Trial 47 finished with value: 0.5667120587045298 and parameters: {'n_estimators': 887, 'learning_rate': 0.02920155389648005, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.6430665877040955, 'colsample_bytree': 0.7380282689317594, 'gamma': 0.18328596504220684, 'reg_alpha': 3.0983737399290676e-06, 'reg_lambda': 18.099857146122265}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:50:42,933] Trial 48 finished with value: 0.5685306432040476 and parameters: {'n_estimators': 1380, 'learning_rate': 0.022588689563984663, 'max_depth': 5, 'min_child_weight': 7, 'subsample': 0.7319711166680948, 'colsample_bytree': 0.6414699779675528, 'gamma': 0.017397871821678682, 'reg_alpha': 1.367051287915127e-07, 'reg_lambda': 10.213500859982158}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:50:55,377] Trial 49 finished with value: 0.5588653902677269 and parameters: {'n_estimators': 1260, 'learning_rate': 0.02626545226837738, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.8961003838565964, 'colsample_bytree': 0.6997551316202222, 'gamma': 0.05168401567498762, 'reg_alpha': 5.364949561035085e-07, 'reg_lambda': 1.9629197544495647}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:51:26,067] Trial 50 finished with value: 0.5770194394151751 and parameters: {'n_estimators': 1325, 'learning_rate': 0.02007299082057169, 'max_depth': 6, 'min_child_weight': 6, 'subsample': 0.8751089279349472, 'colsample_bytree': 0.7736176568520087, 'gamma': 0.128251076505167, 'reg_alpha': 0.04163220519025657, 'reg_lambda': 4.649416269632701}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:51:37,687] Trial 51 finished with value: 0.5598111593377233 and parameters: {'n_estimators': 1106, 'learning_rate': 0.021708194500176855, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.9234625320175208, 'colsample_bytree': 0.6360666260205179, 'gamma': 0.09508140253018411, 'reg_alpha': 2.6862201757970087e-07, 'reg_lambda': 15.084858090257056}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:51:49,096] Trial 52 finished with value: 0.556844204412918 and parameters: {'n_estimators': 1083, 'learning_rate': 0.02145743746959793, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.9974966706473964, 'colsample_bytree': 0.6525337104507146, 'gamma': 0.017678110615804925, 'reg_alpha': 3.996914049714631e-07, 'reg_lambda': 46.279891706366094}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:51:56,777] Trial 53 finished with value: 0.5609168091890026 and parameters: {'n_estimators': 1168, 'learning_rate': 0.11035383235456288, 'max_depth': 4, 'min_child_weight': 6, 'subsample': 0.9991056408546317, 'colsample_bytree': 0.6843360321440304, 'gamma': 0.06620705818077416, 'reg_alpha': 6.58565108332026e-08, 'reg_lambda': 34.38512672686408}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:52:11,879] Trial 54 finished with value: 0.559162191277305 and parameters: {'n_estimators': 1016, 'learning_rate': 0.03229761500871734, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.9824211796074749, 'colsample_bytree': 0.6554744233437922, 'gamma': 0.00300140938228528, 'reg_alpha': 1.8703575877078516e-06, 'reg_lambda': 43.746386702629195}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:52:20,892] Trial 55 finished with value: 0.5574389748883928 and parameters: {'n_estimators': 912, 'learning_rate': 0.023276233640191175, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.9584130549466624, 'colsample_bytree': 0.6217192591666493, 'gamma': 0.0336505897192899, 'reg_alpha': 2.4251741049867087e-08, 'reg_lambda': 0.9584309224163826}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:52:27,500] Trial 56 finished with value: 0.556442092174733 and parameters: {'n_estimators': 836, 'learning_rate': 0.027561048223546936, 'max_depth': 5, 'min_child_weight': 6, 'subsample': 0.9887820731002315, 'colsample_bytree': 0.7106431476713737, 'gamma': 0.268015089656018, 'reg_alpha': 5.182871998678885e-06, 'reg_lambda': 8.248459493015597}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:52:34,172] Trial 57 finished with value: 0.5553244722050629 and parameters: {'n_estimators': 743, 'learning_rate': 0.02759328091567364, 'max_depth': 5, 'min_child_weight': 7, 'subsample': 0.9853136906822301, 'colsample_bytree': 0.7114965264186845, 'gamma': 0.5557386578912242, 'reg_alpha': 6.866284831529075e-06, 'reg_lambda': 6.582910991357466}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:52:39,765] Trial 58 finished with value: 0.5558245101090963 and parameters: {'n_estimators': 674, 'learning_rate': 0.027835115540909172, 'max_depth': 6, 'min_child_weight': 7, 'subsample': 0.9869334993661725, 'colsample_bytree': 0.7130941250162799, 'gamma': 0.5688214237539626, 'reg_alpha': 0.00014661128739851256, 'reg_lambda': 2.5725806701037786}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:52:46,336] Trial 59 finished with value: 0.556802444102588 and parameters: {'n_estimators': 676, 'learning_rate': 0.037970825662412284, 'max_depth': 6, 'min_child_weight': 7, 'subsample': 0.9809473553053231, 'colsample_bytree': 0.7137581500250005, 'gamma': 0.5640345576840217, 'reg_alpha': 6.243508946321709e-05, 'reg_lambda': 0.3919473012851534}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:52:53,524] Trial 60 finished with value: 0.5613761193210627 and parameters: {'n_estimators': 834, 'learning_rate': 0.0275182543667579, 'max_depth': 7, 'min_child_weight': 8, 'subsample': 0.9858266538673316, 'colsample_bytree': 0.7372980463602541, 'gamma': 0.5636238779461598, 'reg_alpha': 0.00028385218401181644, 'reg_lambda': 1.2268948430030562}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:53:00,040] Trial 61 finished with value: 0.5569122081740095 and parameters: {'n_estimators': 671, 'learning_rate': 0.03703394643621816, 'max_depth': 6, 'min_child_weight': 7, 'subsample': 0.9670913679191876, 'colsample_bytree': 0.7125555599503087, 'gamma': 0.5919990876028274, 'reg_alpha': 0.00011219606090653464, 'reg_lambda': 2.5214860597097553}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:53:05,487] Trial 62 finished with value: 0.5608186346915485 and parameters: {'n_estimators': 690, 'learning_rate': 0.03173327764791941, 'max_depth': 6, 'min_child_weight': 7, 'subsample': 0.9818254622241724, 'colsample_bytree': 0.7463480613462049, 'gamma': 0.5657146744857792, 'reg_alpha': 0.001990818960358175, 'reg_lambda': 4.760902408276505}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:53:12,949] Trial 63 finished with value: 0.5592195860512753 and parameters: {'n_estimators': 724, 'learning_rate': 0.02975270345195854, 'max_depth': 6, 'min_child_weight': 8, 'subsample': 0.9875571734168616, 'colsample_bytree': 0.7165725282152575, 'gamma': 0.4985482038325594, 'reg_alpha': 1.2100434218251673e-05, 'reg_lambda': 0.34255313103146495}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:53:18,301] Trial 64 finished with value: 0.5564081323370335 and parameters: {'n_estimators': 600, 'learning_rate': 0.038574623934069914, 'max_depth': 7, 'min_child_weight': 7, 'subsample': 0.9626603303877698, 'colsample_bytree': 0.6737195261998927, 'gamma': 0.5519088744046214, 'reg_alpha': 5.9653119099296756e-05, 'reg_lambda': 0.1670402519497839}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:53:23,666] Trial 65 finished with value: 0.5604963324116754 and parameters: {'n_estimators': 627, 'learning_rate': 0.11971812322057598, 'max_depth': 8, 'min_child_weight': 7, 'subsample': 0.9631429630128154, 'colsample_bytree': 0.6796848185073244, 'gamma': 0.514584958807423, 'reg_alpha': 0.0001288137059247747, 'reg_lambda': 0.1274281032605585}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:53:29,316] Trial 66 finished with value: 0.55875929704484 and parameters: {'n_estimators': 738, 'learning_rate': 0.04330498798093269, 'max_depth': 7, 'min_child_weight': 6, 'subsample': 0.9963274042532407, 'colsample_bytree': 0.6669352707641198, 'gamma': 0.44711452277105135, 'reg_alpha': 5.102424763364783e-06, 'reg_lambda': 0.018501693092289377}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:53:38,275] Trial 67 finished with value: 0.5576607490521204 and parameters: {'n_estimators': 817, 'learning_rate': 0.02804327663592056, 'max_depth': 7, 'min_child_weight': 7, 'subsample': 0.9698009131656476, 'colsample_bytree': 0.7045028408067799, 'gamma': 0.5453677771087858, 'reg_alpha': 3.0438554290944766e-05, 'reg_lambda': 0.19291630160771356}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:53:42,868] Trial 68 finished with value: 0.5542681346016568 and parameters: {'n_estimators': 608, 'learning_rate': 0.03440525281185231, 'max_depth': 5, 'min_child_weight': 6, 'subsample': 0.9582655998985791, 'colsample_bytree': 0.6749851532522321, 'gamma': 0.47955914271039024, 'reg_alpha': 0.0002767778314404181, 'reg_lambda': 0.09612823259596409}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:53:49,014] Trial 69 finished with value: 0.5578612782535275 and parameters: {'n_estimators': 617, 'learning_rate': 0.034764919758392826, 'max_depth': 5, 'min_child_weight': 6, 'subsample': 0.9176582836859454, 'colsample_bytree': 0.6725418242117484, 'gamma': 0.5987458675875797, 'reg_alpha': 0.00025712209670656244, 'reg_lambda': 0.06867139057959919}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:53:55,404] Trial 70 finished with value: 0.571080895435877 and parameters: {'n_estimators': 727, 'learning_rate': 0.034294428229786296, 'max_depth': 5, 'min_child_weight': 7, 'subsample': 0.9380027323777202, 'colsample_bytree': 0.778617050502689, 'gamma': 0.3089014796352945, 'reg_alpha': 0.0036015652382567053, 'reg_lambda': 0.08704792613587271}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:54:04,980] Trial 71 finished with value: 0.5596381834952251 and parameters: {'n_estimators': 787, 'learning_rate': 0.025791218687029754, 'max_depth': 7, 'min_child_weight': 6, 'subsample': 0.9604059107000573, 'colsample_bytree': 0.6780613520758644, 'gamma': 0.5306889340552892, 'reg_alpha': 0.0005859280521797367, 'reg_lambda': 0.10271771325300556}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:54:10,378] Trial 72 finished with value: 0.5550996770763581 and parameters: {'n_estimators': 606, 'learning_rate': 0.02892573157166487, 'max_depth': 5, 'min_child_weight': 6, 'subsample': 0.9733942889130731, 'colsample_bytree': 0.6592327327406757, 'gamma': 0.397987917528075, 'reg_alpha': 0.00017004349166555932, 'reg_lambda': 0.02565023519679248}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:54:17,131] Trial 73 finished with value: 0.5558807918421456 and parameters: {'n_estimators': 600, 'learning_rate': 0.029602656972491644, 'max_depth': 5, 'min_child_weight': 6, 'subsample': 0.9715537157988676, 'colsample_bytree': 0.6603601036949037, 'gamma': 0.3609567005223834, 'reg_alpha': 5.096845831005648e-05, 'reg_lambda': 0.021414280320355205}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:54:22,759] Trial 74 finished with value: 0.5614242465976792 and parameters: {'n_estimators': 606, 'learning_rate': 0.02911151122738058, 'max_depth': 5, 'min_child_weight': 7, 'subsample': 0.9414782731852663, 'colsample_bytree': 0.6551358799352339, 'gamma': 0.3579414246634309, 'reg_alpha': 0.0013963825217981297, 'reg_lambda': 0.02780677371545858}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:54:28,521] Trial 75 finished with value: 0.5541437239374681 and parameters: {'n_estimators': 641, 'learning_rate': 0.032083699924910544, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.973952327609369, 'colsample_bytree': 0.6070455534583215, 'gamma': 0.4160658483772, 'reg_alpha': 6.1012054672777174e-05, 'reg_lambda': 0.009675413126115409}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:54:33,033] Trial 76 finished with value: 0.5564447296240512 and parameters: {'n_estimators': 643, 'learning_rate': 0.03125341586434707, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9755369797295008, 'colsample_bytree': 0.6276271963822081, 'gamma': 0.4191330274067797, 'reg_alpha': 0.00015137993985071571, 'reg_lambda': 0.005655634515786516}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:54:40,496] Trial 77 finished with value: 0.5581638689369796 and parameters: {'n_estimators': 701, 'learning_rate': 0.024564453765513944, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9311834118184898, 'colsample_bytree': 0.6003431515184282, 'gamma': 0.39719913667012763, 'reg_alpha': 1.8345827177543974e-05, 'reg_lambda': 0.011207207249470809}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:54:51,011] Trial 78 finished with value: 0.5678697697079274 and parameters: {'n_estimators': 755, 'learning_rate': 0.032169879603078974, 'max_depth': 5, 'min_child_weight': 6, 'subsample': 0.7065089701352041, 'colsample_bytree': 0.6125754394395572, 'gamma': 0.34766512498502394, 'reg_alpha': 0.0009116583666146733, 'reg_lambda': 0.03380567471683108}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:54:55,069] Trial 79 finished with value: 0.5551227527299465 and parameters: {'n_estimators': 651, 'learning_rate': 0.041262187918267156, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9531489790412742, 'colsample_bytree': 0.6405193958461612, 'gamma': 0.45606134998137615, 'reg_alpha': 0.00018205119140952465, 'reg_lambda': 0.004896250019907533}. Best is trial 21 with value: 0.5536006958373851.
# [I 2025-08-31 14:54:58,910] Trial 80 finished with value: 0.5524993559428598 and parameters: {'n_estimators': 652, 'learning_rate': 0.04629405454659995, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9503330695069633, 'colsample_bytree': 0.6158699088122689, 'gamma': 0.46919891746846837, 'reg_alpha': 0.0003656518238963237, 'reg_lambda': 0.0032210717858849195}. Best is trial 80 with value: 0.5524993559428598.
# [I 2025-08-31 14:55:04,396] Trial 81 finished with value: 0.5515228298728017 and parameters: {'n_estimators': 656, 'learning_rate': 0.04715458921713898, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9452255354855056, 'colsample_bytree': 0.6101532939769815, 'gamma': 0.488320525904814, 'reg_alpha': 0.00019039181658355483, 'reg_lambda': 0.004826302045242722}. Best is trial 81 with value: 0.5515228298728017.
# [I 2025-08-31 14:55:08,108] Trial 82 finished with value: 0.5514061550607916 and parameters: {'n_estimators': 652, 'learning_rate': 0.048078856888208704, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9492085890961818, 'colsample_bytree': 0.6161410554845649, 'gamma': 0.483895850489888, 'reg_alpha': 0.005203963663078901, 'reg_lambda': 0.0024119561817324015}. Best is trial 82 with value: 0.5514061550607916.
# [I 2025-08-31 14:55:11,817] Trial 83 finished with value: 0.5509118319030477 and parameters: {'n_estimators': 648, 'learning_rate': 0.047157910199294426, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9562907603364503, 'colsample_bytree': 0.6119745592580172, 'gamma': 0.48054992682583214, 'reg_alpha': 0.012472578398554708, 'reg_lambda': 0.002702116199717913}. Best is trial 83 with value: 0.5509118319030477.
# [I 2025-08-31 14:55:17,305] Trial 84 finished with value: 0.552305989120371 and parameters: {'n_estimators': 647, 'learning_rate': 0.04771049770420885, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9455637970955306, 'colsample_bytree': 0.6122546818467409, 'gamma': 0.4841942479184306, 'reg_alpha': 0.01660768710910745, 'reg_lambda': 0.002017290657987412}. Best is trial 83 with value: 0.5509118319030477.
# [I 2025-08-31 14:55:21,237] Trial 85 finished with value: 0.5560126510535548 and parameters: {'n_estimators': 706, 'learning_rate': 0.05444973237548817, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9150639483806463, 'colsample_bytree': 0.6122941005763144, 'gamma': 0.4782958465632268, 'reg_alpha': 0.006146582502347669, 'reg_lambda': 0.002227409939345635}. Best is trial 83 with value: 0.5509118319030477.
# [I 2025-08-31 14:55:26,743] Trial 86 finished with value: 0.5502480633271604 and parameters: {'n_estimators': 633, 'learning_rate': 0.04825218157933773, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9317440353977315, 'colsample_bytree': 0.6126467043207855, 'gamma': 0.48407721853449553, 'reg_alpha': 0.014638661479770767, 'reg_lambda': 0.0019635911421719662}. Best is trial 86 with value: 0.5502480633271604.
# [I 2025-08-31 14:55:30,823] Trial 87 finished with value: 0.5541890994062634 and parameters: {'n_estimators': 650, 'learning_rate': 0.04724807381749542, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9042353835887482, 'colsample_bytree': 0.6116535535977929, 'gamma': 0.4854879068066782, 'reg_alpha': 0.012070678447900732, 'reg_lambda': 0.001654427486196022}. Best is trial 86 with value: 0.5502480633271604.
# [I 2025-08-31 14:55:35,294] Trial 88 finished with value: 0.5571495954959049 and parameters: {'n_estimators': 662, 'learning_rate': 0.04723816314587908, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.8862500667725963, 'colsample_bytree': 0.6102522316997563, 'gamma': 0.4349651190896629, 'reg_alpha': 0.014568752388866771, 'reg_lambda': 0.0017086640752229008}. Best is trial 86 with value: 0.5502480633271604.
# [I 2025-08-31 14:55:40,998] Trial 89 finished with value: 0.558130193004938 and parameters: {'n_estimators': 800, 'learning_rate': 0.06344022524056943, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9009704311237267, 'colsample_bytree': 0.6192248872715228, 'gamma': 0.48723697408833794, 'reg_alpha': 0.2268226982123867, 'reg_lambda': 0.002791573059783883}. Best is trial 86 with value: 0.5502480633271604.
# [I 2025-08-31 14:55:45,587] Trial 90 finished with value: 0.5576713221737098 and parameters: {'n_estimators': 639, 'learning_rate': 0.04791801561119007, 'max_depth': 6, 'min_child_weight': 8, 'subsample': 0.9281445901554193, 'colsample_bytree': 0.6324482860062354, 'gamma': 0.4646265945640292, 'reg_alpha': 0.06635163038334115, 'reg_lambda': 0.004796181205623889}. Best is trial 86 with value: 0.5502480633271604.
# [I 2025-08-31 14:55:50,922] Trial 91 finished with value: 0.5536409916640599 and parameters: {'n_estimators': 767, 'learning_rate': 0.05112633120960695, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.946570070231599, 'colsample_bytree': 0.6076955293968372, 'gamma': 0.5141462487783663, 'reg_alpha': 0.024703726586207356, 'reg_lambda': 0.001128828991107864}. Best is trial 86 with value: 0.5502480633271604.
# [I 2025-08-31 14:55:54,865] Trial 92 finished with value: 0.5526589684337199 and parameters: {'n_estimators': 707, 'learning_rate': 0.05123489220849764, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9430934331096771, 'colsample_bytree': 0.6071604818518522, 'gamma': 0.5114286037147834, 'reg_alpha': 0.02148843248970708, 'reg_lambda': 0.0010338581815877792}. Best is trial 86 with value: 0.5502480633271604.
# [I 2025-08-31 14:55:58,549] Trial 93 finished with value: 0.5532925198907608 and parameters: {'n_estimators': 709, 'learning_rate': 0.05142568779782588, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9411666985884269, 'colsample_bytree': 0.6045402129346106, 'gamma': 0.5168545658232184, 'reg_alpha': 0.039076742602269024, 'reg_lambda': 0.0010313706154746552}. Best is trial 86 with value: 0.5502480633271604.
# [I 2025-08-31 14:56:04,130] Trial 94 finished with value: 0.5532666685626546 and parameters: {'n_estimators': 768, 'learning_rate': 0.05121632650494451, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.94121025357949, 'colsample_bytree': 0.6258082554269171, 'gamma': 0.5185938678734999, 'reg_alpha': 0.027726137063279428, 'reg_lambda': 0.0010913938445727613}. Best is trial 86 with value: 0.5502480633271604.
# [I 2025-08-31 14:56:07,866] Trial 95 finished with value: 0.5576787976108675 and parameters: {'n_estimators': 716, 'learning_rate': 0.06109505571339041, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9115294841432467, 'colsample_bytree': 0.6288080939198577, 'gamma': 0.5299900785235959, 'reg_alpha': 0.00717179608504451, 'reg_lambda': 0.0034357634823982295}. Best is trial 86 with value: 0.5502480633271604.
# [I 2025-08-31 14:56:11,686] Trial 96 finished with value: 0.5534082639378768 and parameters: {'n_estimators': 701, 'learning_rate': 0.054126116037277315, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9336045425731467, 'colsample_bytree': 0.6199811119107256, 'gamma': 0.5025142341996797, 'reg_alpha': 0.0294641188943048, 'reg_lambda': 0.0020589749721549614}. Best is trial 86 with value: 0.5502480633271604.
# [I 2025-08-31 14:56:17,138] Trial 97 finished with value: 0.5526439790277398 and parameters: {'n_estimators': 697, 'learning_rate': 0.05434161147440255, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9337475795603651, 'colsample_bytree': 0.6199260699992891, 'gamma': 0.5045140677882085, 'reg_alpha': 0.028025439042218627, 'reg_lambda': 0.0021968071769749484}. Best is trial 86 with value: 0.5502480633271604.
# [I 2025-08-31 14:56:21,381] Trial 98 finished with value: 0.5550774561821333 and parameters: {'n_estimators': 684, 'learning_rate': 0.04426392729467277, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9266043624873435, 'colsample_bytree': 0.6413621867676496, 'gamma': 0.4526306270628105, 'reg_alpha': 0.09387298141377966, 'reg_lambda': 0.0010300890592027149}. Best is trial 86 with value: 0.5502480633271604.
# [I 2025-08-31 14:56:25,107] Trial 99 finished with value: 0.5505496004613317 and parameters: {'n_estimators': 770, 'learning_rate': 0.05873046880168358, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9423814519730301, 'colsample_bytree': 0.6025320655184149, 'gamma': 0.5145538870547632, 'reg_alpha': 0.04548278095469603, 'reg_lambda': 0.0013633526062172587}. Best is trial 86 with value: 0.5502480633271604.
# [I 2025-08-31 14:56:30,909] Trial 100 finished with value: 0.5557298109531067 and parameters: {'n_estimators': 763, 'learning_rate': 0.057999948962146705, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9210264590765939, 'colsample_bytree': 0.6190668234143135, 'gamma': 0.4361543590837309, 'reg_alpha': 0.44151947140586323, 'reg_lambda': 0.0014149916457982688}. Best is trial 86 with value: 0.5502480633271604.
# [I 2025-08-31 14:56:35,121] Trial 101 finished with value: 0.5566750285306077 and parameters: {'n_estimators': 739, 'learning_rate': 0.04541234690832148, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.942970995924395, 'colsample_bytree': 0.6330273362218286, 'gamma': 0.466617321587781, 'reg_alpha': 0.05767218182705065, 'reg_lambda': 0.0023250552166771913}. Best is trial 86 with value: 0.5502480633271604.
# [I 2025-08-31 14:56:40,510] Trial 102 finished with value: 0.5514918065968573 and parameters: {'n_estimators': 684, 'learning_rate': 0.05051434101339252, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9463945812029309, 'colsample_bytree': 0.6038653045818764, 'gamma': 0.5144251970489525, 'reg_alpha': 0.15887455849231835, 'reg_lambda': 0.003301841338971901}. Best is trial 86 with value: 0.5502480633271604.
# [I 2025-08-31 14:56:44,113] Trial 103 finished with value: 0.5531658884101163 and parameters: {'n_estimators': 670, 'learning_rate': 0.05811607385138111, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.950424198736207, 'colsample_bytree': 0.6255279341795975, 'gamma': 0.49245113070594587, 'reg_alpha': 0.0070243768837882645, 'reg_lambda': 0.0038238328140562275}. Best is trial 86 with value: 0.5502480633271604.
# [I 2025-08-31 14:56:47,532] Trial 104 finished with value: 0.5538010952933786 and parameters: {'n_estimators': 676, 'learning_rate': 0.06970784680793998, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9505267918675844, 'colsample_bytree': 0.6476785457717665, 'gamma': 0.494175982652511, 'reg_alpha': 0.14983917876076921, 'reg_lambda': 0.0035602531694944365}. Best is trial 86 with value: 0.5502480633271604.
# [I 2025-08-31 14:56:51,407] Trial 105 finished with value: 0.5519163945688488 and parameters: {'n_estimators': 656, 'learning_rate': 0.05865410270742226, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9340347326322487, 'colsample_bytree': 0.616335915679474, 'gamma': 0.47331324901560906, 'reg_alpha': 0.9038321082448602, 'reg_lambda': 0.006282267415749888}. Best is trial 86 with value: 0.5502480633271604.
# [I 2025-08-31 14:56:56,105] Trial 106 finished with value: 0.5516612254032603 and parameters: {'n_estimators': 625, 'learning_rate': 0.04927831880850054, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.934090035653514, 'colsample_bytree': 0.6004277536753039, 'gamma': 0.5388903009849009, 'reg_alpha': 0.8842118828595347, 'reg_lambda': 0.006865797744724877}. Best is trial 86 with value: 0.5502480633271604.
# [I 2025-08-31 14:56:59,978] Trial 107 finished with value: 0.5548217158309177 and parameters: {'n_estimators': 663, 'learning_rate': 0.05506479650562222, 'max_depth': 6, 'min_child_weight': 8, 'subsample': 0.8915422168461384, 'colsample_bytree': 0.60122089973911, 'gamma': 0.5784761443652294, 'reg_alpha': 0.8054439054788143, 'reg_lambda': 0.006754074615869849}. Best is trial 86 with value: 0.5502480633271604.
# [I 2025-08-31 14:57:04,322] Trial 108 finished with value: 0.5531201902361091 and parameters: {'n_estimators': 628, 'learning_rate': 0.049616449421906, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9327876912193679, 'colsample_bytree': 0.6164937851497259, 'gamma': 0.5392349718915957, 'reg_alpha': 0.5141561114053549, 'reg_lambda': 0.002817117769057758}. Best is trial 86 with value: 0.5502480633271604.
# [I 2025-08-31 14:57:10,104] Trial 109 finished with value: 0.5663087113458404 and parameters: {'n_estimators': 631, 'learning_rate': 0.046016508207024034, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.8111545964823801, 'colsample_bytree': 0.6353430340659325, 'gamma': 0.47044394043343496, 'reg_alpha': 0.23101055036037335, 'reg_lambda': 0.006961024559901859}. Best is trial 86 with value: 0.5502480633271604.
# [I 2025-08-31 14:57:15,325] Trial 110 finished with value: 0.5739499211260145 and parameters: {'n_estimators': 739, 'learning_rate': 0.053113855021115985, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.8594467561384094, 'colsample_bytree': 0.9236455598554032, 'gamma': 0.5016048431206094, 'reg_alpha': 0.7673136924452344, 'reg_lambda': 0.0044102226629932776}. Best is trial 86 with value: 0.5502480633271604.
# [I 2025-08-31 14:57:20,939] Trial 111 finished with value: 0.5501536274771258 and parameters: {'n_estimators': 692, 'learning_rate': 0.04921873782126873, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9260317312141382, 'colsample_bytree': 0.6013821628565779, 'gamma': 0.5074944456796654, 'reg_alpha': 0.011268251207526897, 'reg_lambda': 0.0015507958002651883}. Best is trial 111 with value: 0.5501536274771258.
# [I 2025-08-31 14:57:24,565] Trial 112 finished with value: 0.5515864262445573 and parameters: {'n_estimators': 691, 'learning_rate': 0.057128339533600726, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9233955322777806, 'colsample_bytree': 0.614351519162345, 'gamma': 0.5298909158645037, 'reg_alpha': 0.009244542618068282, 'reg_lambda': 0.012781249231255397}. Best is trial 111 with value: 0.5501536274771258.
# [I 2025-08-31 14:57:35,051] Trial 113 finished with value: 0.6057550530578252 and parameters: {'n_estimators': 653, 'learning_rate': 0.04234512360027561, 'max_depth': 9, 'min_child_weight': 8, 'subsample': 0.9115184268312702, 'colsample_bytree': 0.9824037094657994, 'gamma': 0.5353258863378805, 'reg_alpha': 0.00367905324221513, 'reg_lambda': 0.0013851238791729719}. Best is trial 111 with value: 0.5501536274771258.
# [I 2025-08-31 14:57:38,587] Trial 114 finished with value: 0.5536416098659344 and parameters: {'n_estimators': 627, 'learning_rate': 0.06048788124478875, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9233329984142707, 'colsample_bytree': 0.6142173160203531, 'gamma': 0.4805824900488707, 'reg_alpha': 0.009653024885899097, 'reg_lambda': 0.011690347373964106}. Best is trial 111 with value: 0.5501536274771258.
# ...
# [I 2025-08-31 15:01:18,465] Trial 163 finished with value: 0.5545448781494551 and parameters: {'n_estimators': 718, 'learning_rate': 0.04743272004946838, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9502416837138848, 'colsample_bytree': 0.6113579475949993, 'gamma': 0.4756443126777118, 'reg_alpha': 0.25878502033351497, 'reg_lambda': 0.004421867298218574}. Best is trial 123 with value: 0.5487063948839573.
# [I 2025-08-31 15:01:22,320] Trial 164 finished with value: 0.5535698491943458 and parameters: {'n_estimators': 681, 'learning_rate': 0.0462665234261162, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9414957169487903, 'colsample_bytree': 0.6144982285882737, 'gamma': 0.5058483139036566, 'reg_alpha': 0.11097736333815011, 'reg_lambda': 0.0034285343483644215}. Best is trial 123 with value: 0.5487063948839573.
# [I 2025-08-31 15:01:27,610] Trial 165 finished with value: 0.5524087266335364 and parameters: {'n_estimators': 648, 'learning_rate': 0.052832307879799395, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9614048936236632, 'colsample_bytree': 0.6075781037720313, 'gamma': 0.4927238137839255, 'reg_alpha': 0.005305357039195963, 'reg_lambda': 0.005153880467498991}. Best is trial 123 with value: 0.5487063948839573.
# [I 2025-08-31 15:01:33,145] Trial 166 finished with value: 0.5576898195363167 and parameters: {'n_estimators': 603, 'learning_rate': 0.042101213118873985, 'max_depth': 8, 'min_child_weight': 8, 'subsample': 0.967525849093664, 'colsample_bytree': 0.6209313132580491, 'gamma': 0.5118540143213839, 'reg_alpha': 0.04624422687230594, 'reg_lambda': 0.012830398253228532}. Best is trial 123 with value: 0.5487063948839573.
# [I 2025-08-31 15:01:39,057] Trial 167 finished with value: 0.5583426251317448 and parameters: {'n_estimators': 747, 'learning_rate': 0.039514486736101445, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9529669958178909, 'colsample_bytree': 0.6371330887012174, 'gamma': 0.5283262026249951, 'reg_alpha': 0.3293768460788399, 'reg_lambda': 0.0022938216830381947}. Best is trial 123 with value: 0.5487063948839573.
# [I 2025-08-31 15:01:43,050] Trial 168 finished with value: 0.5560814614075361 and parameters: {'n_estimators': 684, 'learning_rate': 0.04485183315335707, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9413185617830406, 'colsample_bytree': 0.6082647428157325, 'gamma': 0.47392565136828096, 'reg_alpha': 0.008178625404950944, 'reg_lambda': 0.0011792355267642857}. Best is trial 123 with value: 0.5487063948839573.
# [I 2025-08-31 15:01:47,203] Trial 169 finished with value: 0.5586048669149069 and parameters: {'n_estimators': 642, 'learning_rate': 0.050587504825477594, 'max_depth': 6, 'min_child_weight': 8, 'subsample': 0.914156725886623, 'colsample_bytree': 0.6290444058073983, 'gamma': 0.5760895665203742, 'reg_alpha': 0.1957129706863833, 'reg_lambda': 0.0028839269422920363}. Best is trial 123 with value: 0.5487063948839573.
# [I 2025-08-31 15:01:52,281] Trial 170 finished with value: 0.5560290809631451 and parameters: {'n_estimators': 664, 'learning_rate': 0.0787387556700517, 'max_depth': 5, 'min_child_weight': 7, 'subsample': 0.9306209556449987, 'colsample_bytree': 0.6174345045451499, 'gamma': 0.49699057174222977, 'reg_alpha': 0.08169695863602419, 'reg_lambda': 0.0038783453320848766}. Best is trial 123 with value: 0.5487063948839573.
# [I 2025-08-31 15:01:58,564] Trial 171 finished with value: 0.5500091045931939 and parameters: {'n_estimators': 1701, 'learning_rate': 0.04881204376292798, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9365467258293713, 'colsample_bytree': 0.6063153547802969, 'gamma': 0.5370877715824904, 'reg_alpha': 0.5609431739996561, 'reg_lambda': 0.007364700138505652}. Best is trial 123 with value: 0.5487063948839573.
# [I 2025-08-31 15:02:05,913] Trial 172 finished with value: 0.5519704698419872 and parameters: {'n_estimators': 1502, 'learning_rate': 0.04841683795761463, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9473115276259386, 'colsample_bytree': 0.6074825306209247, 'gamma': 0.5465876513047577, 'reg_alpha': 0.6201607893277914, 'reg_lambda': 0.005796203720817649}. Best is trial 123 with value: 0.5487063948839573.
# [I 2025-08-31 15:02:11,520] Trial 173 finished with value: 0.5517787596918489 and parameters: {'n_estimators': 1418, 'learning_rate': 0.04642438300502894, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9575436306308537, 'colsample_bytree': 0.6140728651903896, 'gamma': 0.5306874768526615, 'reg_alpha': 0.3211369880575782, 'reg_lambda': 0.008892030673272164}. Best is trial 123 with value: 0.5487063948839573.
# [I 2025-08-31 15:02:18,857] Trial 174 finished with value: 0.5535637403856287 and parameters: {'n_estimators': 1646, 'learning_rate': 0.0978003205640055, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9384018325652698, 'colsample_bytree': 0.6238782644084763, 'gamma': 0.5153267319326948, 'reg_alpha': 0.15488421849184883, 'reg_lambda': 0.0017583117697771119}. Best is trial 123 with value: 0.5487063948839573.
# [I 2025-08-31 15:02:24,326] Trial 175 finished with value: 0.5653693213217779 and parameters: {'n_estimators': 869, 'learning_rate': 0.09026194513798215, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.6747991649609034, 'colsample_bytree': 0.6064878179436008, 'gamma': 0.5579100431088398, 'reg_alpha': 0.02238629217487085, 'reg_lambda': 0.004240881464605624}. Best is trial 123 with value: 0.5487063948839573.
# [I 2025-08-31 15:02:30,221] Trial 176 finished with value: 0.5528313443844578 and parameters: {'n_estimators': 728, 'learning_rate': 0.045214212213652565, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9237513575629595, 'colsample_bytree': 0.6000548099678632, 'gamma': 0.48890525054428036, 'reg_alpha': 0.012207129591327085, 'reg_lambda': 0.0021661522873616273}. Best is trial 123 with value: 0.5487063948839573.
# [I 2025-08-31 15:02:33,430] Trial 177 finished with value: 0.5481722855403909 and parameters: {'n_estimators': 770, 'learning_rate': 0.08687056497850233, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.98078728360298, 'colsample_bytree': 0.6166094659707528, 'gamma': 0.5860868430867582, 'reg_alpha': 0.3912023310085762, 'reg_lambda': 0.001001212874937962}. Best is trial 177 with value: 0.5481722855403909.
# [I 2025-08-31 15:02:36,819] Trial 178 finished with value: 0.5482064456030017 and parameters: {'n_estimators': 843, 'learning_rate': 0.08587919573020972, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.979049665021181, 'colsample_bytree': 0.6230397830659841, 'gamma': 0.5870595602469619, 'reg_alpha': 0.4445763679728551, 'reg_lambda': 0.001019198408153008}. Best is trial 177 with value: 0.5481722855403909.
# [I 2025-08-31 15:02:41,916] Trial 179 finished with value: 0.5538401700775958 and parameters: {'n_estimators': 772, 'learning_rate': 0.07263190660875579, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9808620363513936, 'colsample_bytree': 0.6290751823368921, 'gamma': 0.5868719556825359, 'reg_alpha': 0.5043820265969601, 'reg_lambda': 0.0010197678877474623}. Best is trial 177 with value: 0.5481722855403909.
# [I 2025-08-31 15:02:45,090] Trial 180 finished with value: 0.5533037586055416 and parameters: {'n_estimators': 799, 'learning_rate': 0.10136406901688341, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9725624884005082, 'colsample_bytree': 0.6403079118940586, 'gamma': 0.5881465786966749, 'reg_alpha': 0.42065110416136975, 'reg_lambda': 0.0014020653284981064}. Best is trial 177 with value: 0.5481722855403909.
# [I 2025-08-31 15:02:52,141] Trial 181 finished with value: 0.5549313135084285 and parameters: {'n_estimators': 1725, 'learning_rate': 0.08787701525275922, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9814504625688686, 'colsample_bytree': 0.6189706448788372, 'gamma': 0.5753975744279614, 'reg_alpha': 0.2602471902542019, 'reg_lambda': 0.0012495756411269588}. Best is trial 177 with value: 0.5481722855403909.
# [I 2025-08-31 15:02:55,806] Trial 182 finished with value: 0.5492050050057736 and parameters: {'n_estimators': 841, 'learning_rate': 0.09200890518646361, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9668572865990086, 'colsample_bytree': 0.6085204945874897, 'gamma': 0.5658392997485182, 'reg_alpha': 0.35087858405641126, 'reg_lambda': 0.001617290974294941}. Best is trial 177 with value: 0.5481722855403909.
# [I 2025-08-31 15:02:59,102] Trial 183 finished with value: 0.5471091163380692 and parameters: {'n_estimators': 835, 'learning_rate': 0.09607968068574532, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9894332087880474, 'colsample_bytree': 0.6087803462102492, 'gamma': 0.597589098655773, 'reg_alpha': 0.6901641485168402, 'reg_lambda': 0.0016653679648540084}. Best is trial 183 with value: 0.5471091163380692.
# [I 2025-08-31 15:03:02,265] Trial 184 finished with value: 0.5480479731551086 and parameters: {'n_estimators': 828, 'learning_rate': 0.09462703741743432, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9925240015326727, 'colsample_bytree': 0.6121502954174981, 'gamma': 0.5996276928682746, 'reg_alpha': 0.6041388888318516, 'reg_lambda': 0.0015744708016628443}. Best is trial 183 with value: 0.5471091163380692.
# [I 2025-08-31 15:03:07,194] Trial 185 finished with value: 0.5484822504980051 and parameters: {'n_estimators': 828, 'learning_rate': 0.09522273652259683, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.993814101955497, 'colsample_bytree': 0.6236165068619594, 'gamma': 0.5969412980827152, 'reg_alpha': 0.635048180684238, 'reg_lambda': 0.0015879660418471934}. Best is trial 183 with value: 0.5471091163380692.
# [I 2025-08-31 15:03:10,624] Trial 186 finished with value: 0.5490420138385687 and parameters: {'n_estimators': 903, 'learning_rate': 0.09440803968184384, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9929529598568829, 'colsample_bytree': 0.6228761648800922, 'gamma': 0.5989386790467294, 'reg_alpha': 0.6154523382282185, 'reg_lambda': 0.0012623001385418493}. Best is trial 183 with value: 0.5471091163380692.
# [I 2025-08-31 15:03:13,908] Trial 187 finished with value: 0.5513912071609175 and parameters: {'n_estimators': 833, 'learning_rate': 0.09500933690773573, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9894844271902417, 'colsample_bytree': 0.6336328225613248, 'gamma': 0.5989445584527602, 'reg_alpha': 0.7305807097833589, 'reg_lambda': 0.0012897887537972694}. Best is trial 183 with value: 0.5471091163380692.
# [I 2025-08-31 15:03:18,986] Trial 188 finished with value: 0.5504591658686707 and parameters: {'n_estimators': 900, 'learning_rate': 0.10500226665661365, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9928965844093652, 'colsample_bytree': 0.623992677616429, 'gamma': 0.5959729972213939, 'reg_alpha': 0.5310398634499602, 'reg_lambda': 0.001540828210855491}. Best is trial 183 with value: 0.5471091163380692.
# [I 2025-08-31 15:03:22,371] Trial 189 finished with value: 0.5486155903987591 and parameters: {'n_estimators': 906, 'learning_rate': 0.10977352707160318, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9969124452072892, 'colsample_bytree': 0.6251509643434366, 'gamma': 0.5886014844293254, 'reg_alpha': 0.6564070177790454, 'reg_lambda': 0.0010922343681942376}. Best is trial 183 with value: 0.5471091163380692.
# [I 2025-08-31 15:03:25,782] Trial 190 finished with value: 0.5508236313447739 and parameters: {'n_estimators': 920, 'learning_rate': 0.11141137411368365, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9927055913555384, 'colsample_bytree': 0.6445479200933075, 'gamma': 0.5998895453089061, 'reg_alpha': 0.6146764597582544, 'reg_lambda': 0.0010020493131885305}. Best is trial 183 with value: 0.5471091163380692.
# [I 2025-08-31 15:03:30,877] Trial 191 finished with value: 0.5475225452011933 and parameters: {'n_estimators': 944, 'learning_rate': 0.11695281182966424, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9917324543391166, 'colsample_bytree': 0.6424068246909513, 'gamma': 0.5971065172131514, 'reg_alpha': 0.6216792640716611, 'reg_lambda': 0.001007787462600758}. Best is trial 183 with value: 0.5471091163380692.
# [I 2025-08-31 15:03:34,487] Trial 192 finished with value: 0.5486140148447981 and parameters: {'n_estimators': 988, 'learning_rate': 0.11429298645470885, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9900647582757752, 'colsample_bytree': 0.6490590937026763, 'gamma': 0.5985538373160535, 'reg_alpha': 0.5930833168172249, 'reg_lambda': 0.0011449173743233827}. Best is trial 183 with value: 0.5471091163380692.
# [I 2025-08-31 15:03:38,029] Trial 193 finished with value: 0.5521923638686583 and parameters: {'n_estimators': 988, 'learning_rate': 0.11258236344437147, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9989359150596671, 'colsample_bytree': 0.6463437122104596, 'gamma': 0.5920558669648163, 'reg_alpha': 0.9722300152276573, 'reg_lambda': 0.001045437840357785}. Best is trial 183 with value: 0.5471091163380692.
# [I 2025-08-31 15:03:43,299] Trial 194 finished with value: 0.5512396369842049 and parameters: {'n_estimators': 947, 'learning_rate': 0.11342862328637329, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9906016069689929, 'colsample_bytree': 0.6483384349102214, 'gamma': 0.5955814535046745, 'reg_alpha': 0.615554056342104, 'reg_lambda': 0.0010539683762477929}. Best is trial 183 with value: 0.5471091163380692.
# [I 2025-08-31 15:03:46,708] Trial 195 finished with value: 0.552357305559309 and parameters: {'n_estimators': 889, 'learning_rate': 0.1183003797611564, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9940820893907165, 'colsample_bytree': 0.636337187320595, 'gamma': 0.5859893020844992, 'reg_alpha': 0.6454847238735699, 'reg_lambda': 0.0010049362245270676}. Best is trial 183 with value: 0.5471091163380692.
# [I 2025-08-31 15:03:50,102] Trial 196 finished with value: 0.5493030325620063 and parameters: {'n_estimators': 911, 'learning_rate': 0.10499327508627208, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9862432529393023, 'colsample_bytree': 0.6273146165319691, 'gamma': 0.5983875048969376, 'reg_alpha': 0.5097643856125017, 'reg_lambda': 0.0015000797511466645}. Best is trial 183 with value: 0.5471091163380692.
# [I 2025-08-31 15:03:55,172] Trial 197 finished with value: 0.5516708283235364 and parameters: {'n_estimators': 908, 'learning_rate': 0.10470781977617404, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.986443082455522, 'colsample_bytree': 0.6411181910085741, 'gamma': 0.5974971505993679, 'reg_alpha': 0.494745313729199, 'reg_lambda': 0.001535009621139994}. Best is trial 183 with value: 0.5471091163380692.
# [I 2025-08-31 15:03:59,329] Trial 198 finished with value: 0.5502863380265215 and parameters: {'n_estimators': 961, 'learning_rate': 0.11053954751946937, 'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.9975832583983542, 'colsample_bytree': 0.6550930251414913, 'gamma': 0.5996492087156499, 'reg_alpha': 0.7068392655086964, 'reg_lambda': 0.001298015492828062}. Best is trial 183 with value: 0.5471091163380692.
# [I 2025-08-31 15:04:02,842] Trial 199 finished with value: 0.5509725452598676 and parameters: {'n_estimators': 969, 'learning_rate': 0.1049799087030031, 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.999914753322061, 'colsample_bytree': 0.6564752539162128, 'gamma': 0.5779331553789329, 'reg_alpha': 0.9262885855097076, 'reg_lambda': 0.001339971424882702}. Best is trial 183 with value: 0.5471091163380692.
#
# === Best trial ===
# Value (CV RMSE log-target): 0.5471
# n_estimators: 835
# learning_rate: 0.09607968068574532
# max_depth: 5
# min_child_weight: 8
# subsample: 0.9894332087880474
# colsample_bytree: 0.6087803462102492
# gamma: 0.597589098655773
# reg_alpha: 0.6901641485168402
# reg_lambda: 0.0016653679648540084
# CV RMSE std (best trial): 0.0290

# %%
# ---- Train best pipeline on full data & export submission ----
best_model = XGBRegressor(
    objective='reg:squarederror',
    tree_method='hist',
    random_state=42,
    n_jobs=-1,
    **study.best_params
)

best_pipe = Pipeline([('prep', preprocess), ('model', best_model)])
best_pipe.fit(X, y)

# Train fit quality (original scale)
train_pred_log = best_pipe.predict(X)
train_pred = np.expm1(train_pred_log)
true = np.expm1(y)  # because y = log1p(target)
train_rmse = np.sqrt(mean_squared_error(true, train_pred))
print(f"\nTrain RMSE (original scale): {train_rmse:.2f}")

# Predict test and save
if 'X_test' in globals() and X_test is not None and 'test' in globals():
    test_pred_log = best_pipe.predict(X_test)
    test_pred = np.expm1(test_pred_log)
    id_cols = [c for c in ['Item_Identifier','Outlet_Identifier'] if c in X_test.columns]
    submission = __import__('pandas').DataFrame({**{c: X_test[c].values for c in id_cols},
                                                 TARGET: test_pred})
    submission.to_csv('submission_optuna_xgb.csv', index=False)
    print("Saved submission_optuna_xgb_2.csv")
# Out:
# Train RMSE (original scale): 1067.81
# Saved submission_optuna_xgb_2.csv

# %% [markdown]
# # Ensemble

# %%
# ==== Blended Ensemble: XGBoost + LightGBM (GroupKFold OOF) ====
import numpy as np
import pandas as pd
from sklearn.model_selection import GroupKFold
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

# --- Safety checks: we expect these to exist from your previous steps
assert 'X' in globals() and 'y' in globals(), "Need X, y"
assert 'preprocess' in globals(), "Need preprocess (ColumnTransformer)"
assert 'groups' in globals(), "Need groups (e.g., Outlet_Identifier)"
assert 'TARGET' in globals(), "Need TARGET"
X_test_exists = 'X_test' in globals() and X_test is not None and 'test' in globals()

# --- Use your Optuna-best XGB params (from your message)
xgb_params = dict(
    objective='reg:squarederror',
    tree_method='hist',
    random_state=42,
    n_jobs=-1,
    n_estimators=835,
    learning_rate=0.09607968068574532,
    max_depth=5,
    min_child_weight=8,
    subsample=0.9894332087880474,
    colsample_bytree=0.6087803462102492,
    gamma=0.597589098655773,
    reg_alpha=0.6901641485168402,
    reg_lambda=0.0016653679648540084,
)

# --- A strong, general LGBM baseline (you can tune later)
lgb_params = dict(
    n_estimators=1600,
    learning_rate=0.05,
    num_leaves=63,
    max_depth=-1,
    min_child_samples=20,
    subsample=0.9,
    colsample_bytree=0.7,
    reg_alpha=0.3,
    reg_lambda=0.3,
    random_state=42,
    n_jobs=-1
)

pipe_xgb = Pipeline([('prep', preprocess), ('model', XGBRegressor(**xgb_params))])
pipe_lgb = Pipeline([('prep', preprocess), ('model', LGBMRegressor(**lgb_params))])

kf = GroupKFold(n_splits=5)
oof_xgb = np.zeros(len(X))
oof_lgb = np.zeros(len(X))

print("Training OOF models for blending…")
for fold, (tr_idx, va_idx) in enumerate(kf.split(X, y, groups), 1):
    X_tr, X_va = X.iloc[tr_idx], X.iloc[va_idx]
    y_tr, y_va = y[tr_idx], y[va_idx]

    # Fit each model on train fold
    px = Pipeline([('prep', preprocess), ('model', XGBRegressor(**xgb_params))])
    pl = Pipeline([('prep', preprocess), ('model', LGBMRegressor(**lgb_params))])

    px.fit(X_tr, y_tr)
    pl.fit(X_tr, y_tr)

    oof_xgb[va_idx] = px.predict(X_va)
    oof_lgb[va_idx] = pl.predict(X_va)

    rmse_x = np.sqrt(mean_squared_error(y[va_idx], oof_xgb[va_idx]))
    rmse_l = np.sqrt(mean_squared_error(y[va_idx], oof_lgb[va_idx]))
    print(f"  Fold {fold}: XGB RMSE={rmse_x:.4f}  |  LGB RMSE={rmse_l:.4f}")

# Try blend weights and pick the best OOF RMSE (on log-target)
weights = [0.5, 0.55, 0.6, 0.65, 0.7]
best_w, best_rmse = None, 1e9
for w in weights:
    blend = w * oof_xgb + (1 - w) * oof_lgb
    rmse = np.sqrt(mean_squared_error(y, blend))
    print(f"Blend w={w:.2f}  ->  OOF RMSE (log-target): {rmse:.4f}")
    if rmse < best_rmse:
        best_rmse, best_w = rmse, w

print(f"\nBest blend weight: w_xgb={best_w:.2f}, w_lgb={(1-best_w):.2f} | OOF RMSE (log): {best_rmse:.4f}")

# ---- Refit both models on ALL training data
print("\nRefitting both models on all training data…")
final_xgb = Pipeline([('prep', preprocess), ('model', XGBRegressor(**xgb_params))])
final_lgb = Pipeline([('prep', preprocess), ('model', LGBMRegressor(**lgb_params))])

final_xgb.fit(X, y)
final_lgb.fit(X, y)

# Train fit (informational) — original scale
pred_train_log = best_w * final_xgb.predict(X) + (1 - best_w) * final_lgb.predict(X)
pred_train = np.expm1(pred_train_log)
true_train = np.expm1(y)
train_rmse = np.sqrt(mean_squared_error(true_train, pred_train))
print(f"Train RMSE (original scale, blended): {train_rmse:.2f}")

# ---- Predict test & save submission
if X_test_exists:
    pred_test_log = best_w * final_xgb.predict(X_test) + (1 - best_w) * final_lgb.predict(X_test)
    pred_test = np.expm1(pred_test_log)

    id_cols = [c for c in ['Item_Identifier', 'Outlet_Identifier'] if c in X_test.columns]
    submission = pd.DataFrame({**{c: X_test[c].values for c in id_cols},
                               TARGET: pred_test})
    submission.to_csv('submission_ensemble.csv', index=False)
    print("Saved submission_ensemble.csv")
else:
    print("No X_test/test detected — skipped submission write.")
# Out:
# Training OOF models for blending…
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.009900 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1517
# [LightGBM] [Info] Number of data points in the train set: 7060, number of used features: 57
# [LightGBM] [Info] Start training from score 7.331234
#   Fold 1: XGB RMSE=0.5585  |  LGB RMSE=0.6570
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000726 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1520
# [LightGBM] [Info] Number of data points in the train set: 7036, number of used features: 57
# [LightGBM] [Info] Start training from score 7.412878
#   Fold 2: XGB RMSE=0.5954  |  LGB RMSE=0.6445
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000675 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1519
# [LightGBM] [Info] Number of data points in the train set: 6664, number of used features: 58
# [LightGBM] [Info] Start training from score 7.247280
#   Fold 3: XGB RMSE=0.5364  |  LGB RMSE=0.5946
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000774 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1515
# [LightGBM] [Info] Number of data points in the train set: 6665, number of used features: 57
# [LightGBM] [Info] Start training from score 7.260624
#   Fold 4: XGB RMSE=0.5376  |  LGB RMSE=0.6529
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000683 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1522
# [LightGBM] [Info] Number of data points in the train set: 6667, number of used features: 58
# [LightGBM] [Info] Start training from score 7.228934
#   Fold 5: XGB RMSE=0.5078  |  LGB RMSE=0.5714
# Blend w=0.50  ->  OOF RMSE (log-target): 0.5645
# Blend w=0.55  ->  OOF RMSE (log-target): 0.5607
# Blend w=0.60  ->  OOF RMSE (log-target): 0.5573
# Blend w=0.65  ->  OOF RMSE (log-target): 0.5543
# Blend w=0.70  ->  OOF RMSE (log-target): 0.5517
#
# Best blend weight: w_xgb=0.70, w_lgb=0.30 | OOF RMSE (log): 0.5517
#
# Refitting both models on all training data…
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000885 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1540
# [LightGBM] [Info] Number of data points in the train set: 8523, number of used features: 60
# [LightGBM] [Info] Start training from score 7.297863
# Train RMSE (original scale, blended): 842.55
# Saved submission_ensemble.csv
